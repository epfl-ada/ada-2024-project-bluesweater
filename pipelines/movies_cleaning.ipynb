# %% [markdown]
# # Pipeline for CMU data

# %% [markdown]
# Importing necessary librairies and then the CMU data:

# %%
import pandas as pd
import ast

file_path = "../data/movie.metadata.tsv"
df = pd.read_csv(file_path, sep='\t', header=None)
df.head(100)
# Out:
#            0           1                                                  2  \
# 0     975900   /m/03vyhn                                     Ghosts of Mars
# 1    3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2   28463795  /m/0crgdbh                                        Brun bitter
# 3    9363483  /m/0285_cd                                   White Of The Eye
# 4     261236   /m/01mrr1                                  A Woman in Flames
# ..       ...         ...                                                ...
# 95  29832307   /m/061l7z                                The Thirteen Chairs
# 96  24039457  /m/0crx1wl                              ZA: Zombies Anonymous
# 97  31322464  /m/0gj8s31                              Youth Sports Festival
# 98   5894429   /m/0fc8w8                                   Closing the Ring
# 99  12788657  /m/02x4zpv                               The Boston Strangler
#
#              3           4      5  \
# 0   2001-08-24  14010832.0   98.0
# 1   2000-02-16         NaN   95.0
# 2         1988         NaN   83.0
# 3         1987         NaN  110.0
# 4         1983         NaN  106.0
# ..         ...         ...    ...
# 95        1969         NaN   94.0
# 96        2005         NaN  118.0
# 97        1951         NaN    NaN
# 98  2007-09-14         NaN  117.0
# 99        1968  17810894.0  116.0
#
#                                                     6  \
# 0                  {"/m/02h40lc": "English Language"}
# 1                  {"/m/02h40lc": "English Language"}
# 2                  {"/m/05f_3": "Norwegian Language"}
# 3                  {"/m/02h40lc": "English Language"}
# 4                   {"/m/04306rv": "German Language"}
# ..                                                ...
# 95  {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 96                 {"/m/02h40lc": "English Language"}
# 97                  {"/m/04306rv": "German Language"}
# 98                 {"/m/02h40lc": "English Language"}
# 99                 {"/m/02h40lc": "English Language"}
#
#                                                     7  \
# 0           {"/m/09c7w0": "United States of America"}
# 1           {"/m/09c7w0": "United States of America"}
# 2                              {"/m/05b4w": "Norway"}
# 3                      {"/m/07ssc": "United Kingdom"}
# 4                             {"/m/0345h": "Germany"}
# ..                                                ...
# 95                              {"/m/03rjj": "Italy"}
# 96          {"/m/09c7w0": "United States of America"}
# 97         {"/m/03f2w": "German Democratic Republic"}
# 98  {"/m/09c7w0": "United States of America", "/m/...
# 99          {"/m/09c7w0": "United States of America"}
#
#                                                     8
# 0   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1   {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2   {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3   {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                             {"/m/07s9rl0": "Drama"}
# ..                                                ...
# 95  {"/m/05p553": "Comedy film", "/m/01z4y": "Come...
# 96  {"/m/0gf28": "Parody", "/m/0qdzd": "B-movie", ...
# 97  {"/m/01z02hx": "Sports", "/m/0jtdp": "Document...
# 98  {"/m/068d7h": "Romantic drama", "/m/02l7c8": "...
# 99  {"/m/0lsxr": "Crime Fiction", "/m/02n4kr": "My...
#
# [100 rows x 9 columns]

# %% [markdown]
# Setting the column names for our data frame:

# %%
df.columns = [
    'Wikipedia Movie ID',
    'Freebase Movie ID',
    'Movie Name',
    'Release Date',
    'Box Office Revenue',
    'Runtime',
    'Languages',
    'Countries',
    'Genres'
]

# %% [markdown]
# Separating the Freebase codes and names for Languages, Countries, and Genres

# %%
def split_freebase_data(data):
    try:
        parsed_data = ast.literal_eval(data)  
        freebase_ids = [key for key in parsed_data]
        names = [value for value in parsed_data.values()]
        return freebase_ids, names
    except:
        return [], []

# %%
df[['Language Freebase ID', 'Language Name']] = df['Languages'].apply(lambda x: pd.Series(split_freebase_data(x)))
df[['Country Freebase ID', 'Country Name']] = df['Countries'].apply(lambda x: pd.Series(split_freebase_data(x)))
df[['Genre Freebase ID', 'Genre Name']] = df['Genres'].apply(lambda x: pd.Series(split_freebase_data(x)))

# %%
df_cleaned = df.drop(columns=['Languages', 'Countries', 'Genres'])

# %%
df_cleaned.head()
# Out:
#    Wikipedia Movie ID Freebase Movie ID  \
# 0              975900         /m/03vyhn
# 1             3196793         /m/08yl5d
# 2            28463795        /m/0crgdbh
# 3             9363483        /m/0285_cd
# 4              261236         /m/01mrr1
#
#                                           Movie Name Release Date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    Box Office Revenue  Runtime Language Freebase ID         Language Name  \
# 0          14010832.0     98.0         [/m/02h40lc]    [English Language]
# 1                 NaN     95.0         [/m/02h40lc]    [English Language]
# 2                 NaN     83.0           [/m/05f_3]  [Norwegian Language]
# 3                 NaN    110.0         [/m/02h40lc]    [English Language]
# 4                 NaN    106.0         [/m/04306rv]     [German Language]
#
#   Country Freebase ID                Country Name  \
# 0         [/m/09c7w0]  [United States of America]
# 1         [/m/09c7w0]  [United States of America]
# 2          [/m/05b4w]                    [Norway]
# 3          [/m/07ssc]            [United Kingdom]
# 4          [/m/0345h]                   [Germany]
#
#                                    Genre Freebase ID  \
# 0  [/m/01jfsb, /m/06n90, /m/03npn, /m/03k9fj, /m/...
# 1     [/m/02n4kr, /m/03bxz7, /m/07s9rl0, /m/0hj3n01]
# 2                             [/m/0lsxr, /m/07s9rl0]
# 3                  [/m/01jfsb, /m/0glj9q, /m/09blyk]
# 4                                       [/m/07s9rl0]
#
#                                           Genre Name
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]
# 2                             [Crime Fiction, Drama]
# 3  [Thriller, Erotic thriller, Psychological thri...
# 4                                            [Drama]

# %% [markdown]
# Let us load the data into a pickle for further processing and cleaning in the sections and results notebook:

# %%
df_cleaned.to_pickle('../pickles/cmu_movies_df.pkl')
