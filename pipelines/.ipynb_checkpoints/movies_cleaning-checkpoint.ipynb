# %% [markdown]
# # Cleaning up movies meta data

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (2.2.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import ast

# Step 1: Reading the tsv file 
file_path = "../data/movie.metadata.tsv"
df = pd.read_csv(file_path, sep='\t', header=None)
df.head(100)
# Out:
#            0           1                                                  2  \
# 0     975900   /m/03vyhn                                     Ghosts of Mars
# 1    3196793   /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 2   28463795  /m/0crgdbh                                        Brun bitter
# 3    9363483  /m/0285_cd                                   White Of The Eye
# 4     261236   /m/01mrr1                                  A Woman in Flames
# ..       ...         ...                                                ...
# 95  29832307   /m/061l7z                                The Thirteen Chairs
# 96  24039457  /m/0crx1wl                              ZA: Zombies Anonymous
# 97  31322464  /m/0gj8s31                              Youth Sports Festival
# 98   5894429   /m/0fc8w8                                   Closing the Ring
# 99  12788657  /m/02x4zpv                               The Boston Strangler
#
#              3           4      5  \
# 0   2001-08-24  14010832.0   98.0
# 1   2000-02-16         NaN   95.0
# 2         1988         NaN   83.0
# 3         1987         NaN  110.0
# 4         1983         NaN  106.0
# ..         ...         ...    ...
# 95        1969         NaN   94.0
# 96        2005         NaN  118.0
# 97        1951         NaN    NaN
# 98  2007-09-14         NaN  117.0
# 99        1968  17810894.0  116.0
#
#                                                     6  \
# 0                  {"/m/02h40lc": "English Language"}
# 1                  {"/m/02h40lc": "English Language"}
# 2                  {"/m/05f_3": "Norwegian Language"}
# 3                  {"/m/02h40lc": "English Language"}
# 4                   {"/m/04306rv": "German Language"}
# ..                                                ...
# 95  {"/m/02bjrlw": "Italian Language", "/m/02h40lc...
# 96                 {"/m/02h40lc": "English Language"}
# 97                  {"/m/04306rv": "German Language"}
# 98                 {"/m/02h40lc": "English Language"}
# 99                 {"/m/02h40lc": "English Language"}
#
#                                                     7  \
# 0           {"/m/09c7w0": "United States of America"}
# 1           {"/m/09c7w0": "United States of America"}
# 2                              {"/m/05b4w": "Norway"}
# 3                      {"/m/07ssc": "United Kingdom"}
# 4                             {"/m/0345h": "Germany"}
# ..                                                ...
# 95                              {"/m/03rjj": "Italy"}
# 96          {"/m/09c7w0": "United States of America"}
# 97         {"/m/03f2w": "German Democratic Republic"}
# 98  {"/m/09c7w0": "United States of America", "/m/...
# 99          {"/m/09c7w0": "United States of America"}
#
#                                                     8
# 0   {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1   {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2   {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3   {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                             {"/m/07s9rl0": "Drama"}
# ..                                                ...
# 95  {"/m/05p553": "Comedy film", "/m/01z4y": "Come...
# 96  {"/m/0gf28": "Parody", "/m/0qdzd": "B-movie", ...
# 97  {"/m/01z02hx": "Sports", "/m/0jtdp": "Document...
# 98  {"/m/068d7h": "Romantic drama", "/m/02l7c8": "...
# 99  {"/m/0lsxr": "Crime Fiction", "/m/02n4kr": "My...
#
# [100 rows x 9 columns]

# %%
# Step 2: Setting column names
df.columns = [
    'Wikipedia Movie ID',
    'Freebase Movie ID',
    'Movie Name',
    'Release Date',
    'Box Office Revenue',
    'Runtime',
    'Languages',
    'Countries',
    'Genres'
]

# %%
# Step 3: Separate the Freebase codes and names for Languages, Countries, and Genres
def split_freebase_data(data):
    try:
        parsed_data = ast.literal_eval(data)  
        freebase_ids = [key for key in parsed_data]
        names = [value for value in parsed_data.values()]
        return freebase_ids, names
    except:
        return [], []

# %%
# Step 4: Apply the split function to Languages, Countries, and Genres columns
df[['Language Freebase ID', 'Language Name']] = df['Languages'].apply(lambda x: pd.Series(split_freebase_data(x)))
df[['Country Freebase ID', 'Country Name']] = df['Countries'].apply(lambda x: pd.Series(split_freebase_data(x)))
df[['Genre Freebase ID', 'Genre Name']] = df['Genres'].apply(lambda x: pd.Series(split_freebase_data(x)))

# %%
# Step 5: Dropping original columns (Languages, Countries, Genres)
df_cleaned = df.drop(columns=['Languages', 'Countries', 'Genres'])

# %%
# Step 6: Display the cleaned data
df_cleaned.head()
# Out:
#    Wikipedia Movie ID Freebase Movie ID  \
# 0              975900         /m/03vyhn
# 1             3196793         /m/08yl5d
# 2            28463795        /m/0crgdbh
# 3             9363483        /m/0285_cd
# 4              261236         /m/01mrr1
#
#                                           Movie Name Release Date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    Box Office Revenue  Runtime Language Freebase ID         Language Name  \
# 0          14010832.0     98.0         [/m/02h40lc]    [English Language]
# 1                 NaN     95.0         [/m/02h40lc]    [English Language]
# 2                 NaN     83.0           [/m/05f_3]  [Norwegian Language]
# 3                 NaN    110.0         [/m/02h40lc]    [English Language]
# 4                 NaN    106.0         [/m/04306rv]     [German Language]
#
#   Country Freebase ID                Country Name  \
# 0         [/m/09c7w0]  [United States of America]
# 1         [/m/09c7w0]  [United States of America]
# 2          [/m/05b4w]                    [Norway]
# 3          [/m/07ssc]            [United Kingdom]
# 4          [/m/0345h]                   [Germany]
#
#                                    Genre Freebase ID  \
# 0  [/m/01jfsb, /m/06n90, /m/03npn, /m/03k9fj, /m/...
# 1     [/m/02n4kr, /m/03bxz7, /m/07s9rl0, /m/0hj3n01]
# 2                             [/m/0lsxr, /m/07s9rl0]
# 3                  [/m/01jfsb, /m/0glj9q, /m/09blyk]
# 4                                       [/m/07s9rl0]
#
#                                           Genre Name
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]
# 2                             [Crime Fiction, Drama]
# 3  [Thriller, Erotic thriller, Psychological thri...
# 4                                            [Drama]

# %%
# Step 7: Saving it as pickle for further use
df_cleaned.to_pickle('../pickles/cmu_movies_df.pkl')

# %%
import pandas as pd

df = pd.read_pickle('../pickles/cmu_movies_df.pkl')
df.head()
# Out:
#    Wikipedia Movie ID Freebase Movie ID  \
# 0              975900         /m/03vyhn
# 1             3196793         /m/08yl5d
# 2            28463795        /m/0crgdbh
# 3             9363483        /m/0285_cd
# 4              261236         /m/01mrr1
#
#                                           Movie Name Release Date  \
# 0                                     Ghosts of Mars   2001-08-24
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                        Brun bitter         1988
# 3                                   White Of The Eye         1987
# 4                                  A Woman in Flames         1983
#
#    Box Office Revenue  Runtime Language Freebase ID         Language Name  \
# 0          14010832.0     98.0         [/m/02h40lc]    [English Language]
# 1                 NaN     95.0         [/m/02h40lc]    [English Language]
# 2                 NaN     83.0           [/m/05f_3]  [Norwegian Language]
# 3                 NaN    110.0         [/m/02h40lc]    [English Language]
# 4                 NaN    106.0         [/m/04306rv]     [German Language]
#
#   Country Freebase ID                Country Name  \
# 0         [/m/09c7w0]  [United States of America]
# 1         [/m/09c7w0]  [United States of America]
# 2          [/m/05b4w]                    [Norway]
# 3          [/m/07ssc]            [United Kingdom]
# 4          [/m/0345h]                   [Germany]
#
#                                    Genre Freebase ID  \
# 0  [/m/01jfsb, /m/06n90, /m/03npn, /m/03k9fj, /m/...
# 1     [/m/02n4kr, /m/03bxz7, /m/07s9rl0, /m/0hj3n01]
# 2                             [/m/0lsxr, /m/07s9rl0]
# 3                  [/m/01jfsb, /m/0glj9q, /m/09blyk]
# 4                                       [/m/07s9rl0]
#
#                                           Genre Name
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]
# 2                             [Crime Fiction, Drama]
# 3  [Thriller, Erotic thriller, Psychological thri...
# 4                                            [Drama]

# %%
oscar = pd.read_pickle('../pickles/oskar_df.pkl')
imdb = pd.read_pickle('../pickles/imdb_data.pkl')
cmu = pd.read_pickle('../pickles/cmu_movies_df.pkl')
rotten = pd.read_pickle('../pickles/rotten_tomatoes.pkl')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages/pandas/io/pickle.py:202, in read_pickle(filepath_or_buffer, compression, storage_options)
#     201         warnings.simplefilter("ignore", Warning)
# --> 202         return pickle.load(handles.handle)
#     203 except excs_to_catch:
#     204     # e.g.
#     205     #  "No module named 'pandas.core.sparse.series'"
#     206     #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
#
# ModuleNotFoundError: No module named 'numpy._core'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 4
#       2 imdb = pd.read_pickle('../pickles/imdb_data.pkl')
#       3 cmu = pd.read_pickle('../pickles/cmu_movies_df.pkl')
# ----> 4 rotten = pd.read_pickle('../pickles/rotten_tomatoes.pkl')
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages/pandas/io/pickle.py:207, in read_pickle(filepath_or_buffer, compression, storage_options)
#     202             return pickle.load(handles.handle)
#     203     except excs_to_catch:
#     204         # e.g.
#     205         #  "No module named 'pandas.core.sparse.series'"
#     206         #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 207         return pc.load(handles.handle, encoding=None)
#     208 except UnicodeDecodeError:
#     209     # e.g. can occur for files written in py27; see GH#28645 and GH#31988
#     210     return pc.load(handles.handle, encoding="latin-1")
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages/pandas/compat/pickle_compat.py:231, in load(fh, encoding, is_verbose)
#     228     # "Unpickler" has no attribute "is_verbose"  [attr-defined]
#     229     up.is_verbose = is_verbose  # type: ignore[attr-defined]
# --> 231     return up.load()
#     232 except (ValueError, TypeError):
#     233     raise
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/pickle.py:1212, in _Unpickler.load(self)
#    1210             raise EOFError
#    1211         assert isinstance(key, bytes_types)
# -> 1212         dispatch[key[0]](self)
#    1213 except _Stop as stopinst:
#    1214     return stopinst.value
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/pickle.py:1537, in _Unpickler.load_stack_global(self)
#    1535 if type(name) is not str or type(module) is not str:
#    1536     raise UnpicklingError("STACK_GLOBAL requires str")
# -> 1537 self.append(self.find_class(module, name))
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/site-packages/pandas/compat/pickle_compat.py:162, in Unpickler.find_class(self, module, name)
#     160 key = (module, name)
#     161 module, name = _class_locations_map.get(key, key)
# --> 162 return super().find_class(module, name)
#
# File /opt/anaconda3/envs/py3-9-18/lib/python3.9/pickle.py:1579, in _Unpickler.find_class(self, module, name)
#    1577     elif module in _compat_pickle.IMPORT_MAPPING:
#    1578         module = _compat_pickle.IMPORT_MAPPING[module]
# -> 1579 __import__(module, level=0)
#    1580 if self.proto >= 4:
#    1581     return _getattribute(sys.modules[module], name)[0]
#
# ModuleNotFoundError: No module named 'numpy._core'
